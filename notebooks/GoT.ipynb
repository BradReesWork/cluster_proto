# %%
import cudf
import cugraph

# %%
gdf = cudf.read_csv('./Game_Of_Thrones.csv')

# %%
gdf.head()
# Out:
#    Episodio                                 Titulo  Votos  Rating  \
# 0       1.1                       Winter Is Coming  39826     9.1
# 1       1.2                          The Kingsroad  30209     8.8
# 2       1.3                              Lord Snow  28560     8.7
# 3       1.4  Cripples, Bastards, and Broken Things  27106     8.8
# 4       1.5                  The Wolf and the Lion  28215     9.1
#
#   F.Transmisión
# 0    8 May 2011
# 1   15 May 2011
# 2    1 May 2011
# 3    8 May 2011
# 4   15 May 2011

# %%
len(gdf)
# Out:
# 67

# %%
gdf
# Out:
#     Episodio                                 Titulo  Votos  Rating  \
# 0        1.1                       Winter Is Coming  39826     9.1
# 1        1.2                          The Kingsroad  30209     8.8
# 2        1.3                              Lord Snow  28560     8.7
# 3        1.4  Cripples, Bastards, and Broken Things  27106     8.8
# 4        1.5                  The Wolf and the Lion  28215     9.1
# ..       ...                                    ...    ...     ...
# 62       7.3                    The Queen's Justice  42407     9.2
# 63       7.4                      The Spoils of War  80353     9.8
# 64       7.5                              Eastwatch  40454     8.8
# 65       7.6                        Beyond the Wall  58990     9.0
# 66       7.7                The Dragon and the Wolf  58571     9.4
#
#    F.Transmisión
# 0     8 May 2011
# 1    15 May 2011
# 2     1 May 2011
# 3     8 May 2011
# 4    15 May 2011
# ..           ...
# 62  30 Jul. 2017
# ...
